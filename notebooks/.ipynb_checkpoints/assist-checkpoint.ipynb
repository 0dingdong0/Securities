# %%
import os
import time
import math
import json
import redis
import asyncio
import traceback
from aredis import StrictRedis
from multiprocessing import Process

# %%
from pathlib import Path
os.chdir(Path(os.getcwd()).parent)

# %%
from libs.quotation import Quotation
from libs.dailydata import DailyData
from libs.utils import Utils
from libs.cython.compute import compute_stats

# %%
policy = asyncio.WindowsSelectorEventLoopPolicy()
asyncio.set_event_loop_policy(policy)

# %%
def assist(assist_idx, assist_count):
    
    ar = StrictRedis(host='127.0.0.1', port=6379, db=8)
    data = {}
    task_snapshotting = None
    
    def get_daily_data(date):
        if date not in data:
            dd = DailyData(date, create=False)
            group_size = math.ceil(len(dd.symbols)/assist_count)
            scope = (
                assist_idx*group_size, 
                min((assist_idx+1)*group_size, len(dd.symbols))
            )
            data[date] = (dd, scope)
            
        return data[date]
    
        
    def compute_statistics(date):
#         dd = get_daily_data(date)
#         group_size = math.ceil(len(dd.symbols)/assist_count)
#         scope = (
#             assist_idx*group_size, 
#             min((assist_idx+1)*group_size, len(dd.symbols))
#         )
        dd, scope = get_daily_data(date)
        basics = dd.basics[scope[0]:scope[1], :]
        for _, check_point in enumerate(daily_data.check_points):
            
            snapshot = dd.snapshots[_,scope[0]:scope[1], :]
            statistic = dd.statistic[_,scope[0]:scope[1], :]
            
            time_lapse = dd.get_time_lapse(_)
            ma5pm_anchor_idx = dd.get_ma5pm_anchor_idx(_)
            fs5p = dd.snapshots[ma5pm_anchor_idx,scope[0]:scope[1], :]
            
            compute_stats(snapshot, basics, statistic, fs5p, time_lapse)
            
    
    async def snapshotting(date):
        try:
            dd, scope = get_daily_data(date)
#             dd = get_daily_data(date)
#             group_size = math.ceil(len(dd.symbols)/assist_count)
#             scope = (
#                 assist_idx*group_size, 
#                 min((assist_idx+1)*group_size, len(dd.symbols))
#             )

            q = Quotation(symbols=dd.symbols.tolist()[scope[0]:scope[1]])
            basics = dd.basics[scope[0]:scope[1], :]

            for _, check_point in enumerate(dd.check_points):
                if time.time() > check_point:
                    continue

                delay=(check_point-time.time())
                await asyncio.sleep(max(delay,0))
#                 await asyncio.sleep(5)

                try:
                    await q.snapshot(array=dd.snapshots[_,scope[0]:scope[1],:])

                    snapshot = dd.snapshots[_,scope[0]:scope[1], :]
                    statistic = dd.statistic[_,scope[0]:scope[1], :]

                    time_lapse = dd.get_time_lapse(_)
                    ma5pm_anchor_idx = dd.get_ma5pm_anchor_idx(_)
                    fs5p = dd.snapshots[ma5pm_anchor_idx,scope[0]:scope[1], :]

                    compute_stats(snapshot, basics, statistic, fs5p, time_lapse)

                    await ar.publish(f'hq_assist_{assist_idx}_snapshotting', json.dumps({"status":'successful',"idx":_,'check_point':int(check_point)}))
                        
                except Exception as e:
                    error = {
                        "status": 'failed',
                        "idx": _,
                        'check_point':int(check_point),
                        "exception": str(e),
                        'traceback': traceback.format_exc()
                    }
                    await ar.publish(f'hq_assist_{assist_idx}_snapshotting', json.dumps(error))
                    
#                 finally:
#                     if assist_idx == 0:
#                         dd.incremental_save(_)
                        
        finally:
            await q.exit()
    
    
    async def main():
        
        snapshotting_task = None
        
        while True:
            key, value = await ar.brpop(f'hq_assist_{assist_idx}')
            msg = json.loads(value)
            print(f'Assist[{assist_idx}] {msg}')
            
            if msg['command'] == 'snapshotting':
                snapshotting_task = asyncio.create_task(snapshotting(msg['date']))
                
            elif msg['command'] == 'compute_statistics':
                try:
                    compute_statistics(msg['date'])
                    await ar.lpush(f'hq_assist_{assist_idx}_compute_statistics', json.dumps({"status":'success'}))
                except Exception as e:
                    error = {
                        "status": 'failed',
                        "exception": str(e),
                        'traceback': traceback.format_exc()
                    }
                    await ar.lpush(f'hq_assist_{assist_idx}_compute_statistics', json.dumps(error))
                    
            elif msg['command'] == 'incremental_save':
                dd = get_daily_data(msg['date'])
                dd.incremental_save(msg['idx'])

            elif msg['command'] == 'quit':
                    
                if snapshotting_task and snapshotting_task.done() is False:
                    print(f'Assist[{assist_idx}]: snapshotting_task is going to be canceled')
                    snapshotting_task.cancel()
                    
                print(f'Assist[{assist_idx}]: sharedmemory is going to be closed')
                for date in data:
                    data[date].close_sharedmemory()
                break
                
            else:
                pass
            
#     asyncio.run(main())
    asyncio.create_task(main())
    
    return data
    
# if __name__ == '__main__':
#     rd = redis.Redis(host='127.0.0.1', port=6379, db=8)
#     for key in rd.keys():
#         rd.delete(key)

#     ####
#     Utils.update_symbols()
    
#     symbols = Utils.get_running_symbols()
#     assist_count = math.ceil(len(symbols)/800)+1
    
#     rd.set('hq_assist_count', assist_count)

#     processes = []
#     for _ in range(assist_count):
#         proc = Process(target=assist, args=(_, assist_count))
#         processes.append(proc)
#         proc.start()

#     for proc in processes:
#         proc.join()

# %%
# await asyncio.sleep(int(time.mktime(time.strptime(f'{time.strftime("%Y-%m-%d")} 09:13:00', '%Y-%m-%d %H:%M:%S'))) - time.time()) 

rd = redis.Redis(host='127.0.0.1', port=6379, db=8)

symbol_count = len(Utils.get_symbols()) + 10
assist_count = math.ceil(symbol_count/800)+1

rd.set('hq_assist_count', assist_count)

result = []
for _ in range(assist_count):
    data = assist(_, assist_count)
    result.append(data)
# Out:
# Assist[0] {'command': 'snapshotting', 'date': '20210624'}
# Assist[3] {'command': 'snapshotting', 'date': '20210624'}
# Assist[2] {'command': 'snapshotting', 'date': '20210624'}
# Assist[4] {'command': 'snapshotting', 'date': '20210624'}
# Assist[1] {'command': 'snapshotting', 'date': '20210624'}
# Assist[5] {'command': 'snapshotting', 'date': '20210624'}
# Assist[6] {'command': 'snapshotting', 'date': '20210624'}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 0}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 3}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 4}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 5}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 6}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 7}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 8}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 9}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 10}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 11}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 12}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 13}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 14}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 15}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 16}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 17}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 18}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 19}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 20}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 21}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 22}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 23}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 24}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 25}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 26}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 27}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 28}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 29}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 30}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 31}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 32}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 33}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 34}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 35}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 36}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 37}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 38}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 39}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 40}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 41}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 42}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 43}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 44}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 45}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 46}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 47}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 48}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 49}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 50}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 51}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 52}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 53}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 54}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 55}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 56}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 57}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 58}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 59}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 60}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 61}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 62}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 63}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 64}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 65}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 66}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 67}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 68}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 69}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 70}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 71}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 72}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 73}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 74}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 75}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 76}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 77}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 78}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 79}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 80}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 81}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 82}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 83}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 84}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 85}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 86}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 87}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 88}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 89}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 90}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 91}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 92}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 93}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 94}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 95}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 96}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 97}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx':

# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2538}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2539}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2540}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2541}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2542}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2543}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2544}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2545}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2546}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2547}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2548}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2549}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2550}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2551}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2552}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2553}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2554}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2555}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2556}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2557}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2558}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2559}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2560}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2561}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2562}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2563}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2564}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2565}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2566}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2567}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2568}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2569}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2570}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2571}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2572}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2573}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2574}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2575}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2576}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2577}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2578}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2579}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2580}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2581}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2582}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2583}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2584}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2585}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2586}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2587}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2588}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2589}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2590}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2591}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2592}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2593}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2594}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2595}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2596}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2597}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2598}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2599}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2600}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2601}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2602}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2603}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2604}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2605}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2606}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2607}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2608}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2609}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2610}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2611}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2612}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2613}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 2614}

# %%
result = []
for _ in range(assist_count):
    data = assist(_, assist_count)
    result.append(data)

# %%
date = time.strftime('%Y%m%d')
result[0][date].get_snapshot('13:30:55')

# %%
d = {'k':('v1', 'v2')}
# Out:
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1358}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1359}

# %%
# Out:
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1418}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1419}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1420}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1421}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1422}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1423}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1424}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1425}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1426}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1427}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1428}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1429}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1430}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1431}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1432}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1433}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1434}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1435}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1436}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1437}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1438}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1439}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1440}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1441}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1442}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1443}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1444}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1445}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1446}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1447}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1448}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1449}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1450}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1451}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1452}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1453}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1454}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1455}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1456}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1457}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1458}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1459}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1460}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1461}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1462}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1463}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1464}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1465}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1466}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1467}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1468}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1469}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1470}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1471}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1472}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1473}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1474}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1475}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1476}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1477}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1478}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1479}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1480}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1481}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1482}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1483}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1484}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1485}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1486}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1487}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1488}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1489}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1490}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1491}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1492}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1493}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1494}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1495}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1496}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1497}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1498}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1499}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1500}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1501}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1502}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1503}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1504}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1505}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1506}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1507}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1508}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1509}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1510}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1511}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1512}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1513}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1514}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1515}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1516}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1517}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1518}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1519}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1520}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1521}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1522}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1523}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1524}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1525}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1526}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1527}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1528}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1529}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1530}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1531}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1532}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1533}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1534}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1535}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1536}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1537}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1538}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1539}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1540}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1541}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1542}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1543}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1544}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1545}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1546}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1547}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1548}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1549}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1550}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1551}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1552}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1553}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1554}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1555}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1556}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1557}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1558}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1559}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1560}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1561}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1562}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1563}
# Assist[0] {'command': 'incremental_save', 'date': '20210624', 'idx': 1564}

# %%
date = time.strftime('%Y%m%d')

# %%
securities = result[0][date].get_securities()

# %%
securities.loc['300057']

# %%
############################## TEST #####################################

# %%
check_points = Utils.get_check_points()
symbols = Utils.get_running_symbols()

# %%
date = time.strftime('%Y%m%d')

# %%
data = result[0][date]

# %%
q = Quotation(symbols)
snapshot = await q.snapshot()

market_values = await q.get_market_values()

for _, symbol in enumerate(symbols):
    data.basics[_, 0] = market_values[symbol]['zt_price']
    data.basics[_, 1] = market_values[symbol]['dt_price']
    data.basics[_, 3] = market_values[symbol]['mcap']

await q.exit()

# %%
securities = data.get_securities()
securities

# %%
securities.loc['300057']

# %%
ss = data.get_snapshot('13:07:45')
ss

# %%
ss.loc['600354']

# %%
st = time.time()
for _ in range(len(data.check_points)):
    time_lapse = data.get_time_lapse(_)
    ma5pm_anchor_idx = data.get_ma5pm_anchor_idx(_)
    fs5p = data.snapshots[ma5pm_anchor_idx]
    compute_stats(data.snapshots[_], data.basics, data.statistic[_], fs5p, time_lapse)
et = time.time()
et - st

# %%
data.save()
